# %%
#Arithmetic Operators

a=20
b=21

#addition
c=a+b
print(c)

#subtraction
d=a-b
print(d)

#multiplication
e=a*b
print(e)

#division
f=a/b
print(f)

#modulus
g=a%b
print(g)

#exponential
h=a**b
print(h)

#floor division
i=a//b
print(i)
# Out:
# 41
# -1
# 420
# 0.9523809523809523
# 20
# 2097152000000000000000000000
# 0
